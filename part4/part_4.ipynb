# %%
# !python ../part2/predict.py \
  --sentence "Two boys are sitting on a couch that is red and black." \
  --checkpoint-path ../part4/nmt.model \
  --model-config ../part4/model_config.yaml \
  --vocab-file ../part2/vocab/vocab.json \
  --do-sample \
  --top-k 60 \
  --top-p 0.4 \
  --temperature 0.7
# Out:
# load vocab from ..\part2\vocab\vocab.json
# Load model from ..\part4\nmt.model
# Number of parameters: 8455296 (8.46M)
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\gulla\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Traceback (most recent call last):
#   File "c:\Users\gulla\OneDrive\Documents\uni\nlp\cw2\newcw2\nlp_cw2\part2\predict.py", line 193, in <module>
#     predict(args)
#   File "c:\Users\gulla\OneDrive\Documents\uni\nlp\cw2\newcw2\nlp_cw2\part2\predict.py", line 75, in predict
#     sp.load("vocab/spm.model")
#   File "c:\Users\gulla\OneDrive\Documents\uni\nlp\cw2\newcw2\nlp_cw2\.venv\Lib\site-packages\sentencepiece\__init__.py", line 961, in Load
#     return self.LoadFromFile(model_file)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\gulla\OneDrive\Documents\uni\nlp\cw2\newcw2\nlp_cw2\.venv\Lib\site-packages\sentencepiece\__init__.py", line 316, in LoadFromFile
#     return _sentencepiece.SentencePieceProcessor_LoadFromFile(self, arg)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# OSError: Not found: "vocab/spm.model": No such file or directory Error #2

# %%
# !python ../part2/predict.py \
  --sentence "Two boys are sitting on a couch that is red and black." \
  --checkpoint-path ../part4/nmt.model \
  --model-config ../part4/model_config.yaml \
  --vocab-file ../part2/vocab/vocab.json \
  --do-sample \
  --top-k 50 \
  --top-p 0.9 \
  --temperature 1.0
# Out:
# load vocab from ..\part2\vocab\vocab.json
# Load model from ..\part4\nmt.model
# Number of parameters: 8455296 (8.46M)
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\gulla\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Traceback (most recent call last):
#   File "c:\Users\gulla\OneDrive\Documents\uni\nlp\cw2\newcw2\nlp_cw2\part2\predict.py", line 193, in <module>
#     predict(args)
#   File "c:\Users\gulla\OneDrive\Documents\uni\nlp\cw2\newcw2\nlp_cw2\part2\predict.py", line 75, in predict
#     sp.load("vocab/spm.model")
#   File "c:\Users\gulla\OneDrive\Documents\uni\nlp\cw2\newcw2\nlp_cw2\.venv\Lib\site-packages\sentencepiece\__init__.py", line 961, in Load
#     return self.LoadFromFile(model_file)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\gulla\OneDrive\Documents\uni\nlp\cw2\newcw2\nlp_cw2\.venv\Lib\site-packages\sentencepiece\__init__.py", line 316, in LoadFromFile
#     return _sentencepiece.SentencePieceProcessor_LoadFromFile(self, arg)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# OSError: Not found: "vocab/spm.model": No such file or directory Error #2

# %%
# !python ../part2/predict.py \
  --sentence "Two boys are sitting on a couch that is red and black." \
  --checkpoint-path ../part4/nmt.model \
  --model-config ../part4/model_config.yaml \
  --vocab-file ../part2/vocab/vocab.json \
  --do-sample \
  --top-k 50 \
  --top-p 0.9 \
  --temperature 1.0
# Out:
# load vocab from ..\part2\vocab\vocab.json
# Load model from ..\part4\nmt.model
# Number of parameters: 8455296 (8.46M)
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\gulla\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Traceback (most recent call last):
#   File "c:\Users\gulla\OneDrive\Documents\uni\nlp\cw2\newcw2\nlp_cw2\part2\predict.py", line 193, in <module>
#     predict(args)
#   File "c:\Users\gulla\OneDrive\Documents\uni\nlp\cw2\newcw2\nlp_cw2\part2\predict.py", line 75, in predict
#     sp.load("vocab/spm.model")
#   File "c:\Users\gulla\OneDrive\Documents\uni\nlp\cw2\newcw2\nlp_cw2\.venv\Lib\site-packages\sentencepiece\__init__.py", line 961, in Load
#     return self.LoadFromFile(model_file)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\gulla\OneDrive\Documents\uni\nlp\cw2\newcw2\nlp_cw2\.venv\Lib\site-packages\sentencepiece\__init__.py", line 316, in LoadFromFile
#     return _sentencepiece.SentencePieceProcessor_LoadFromFile(self, arg)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# OSError: Not found: "vocab/spm.model": No such file or directory Error #2

# %%
# !python ../part2/predict.py \
  --sentence "Two boys are sitting on a couch that is red and black." \
  --checkpoint-path ../part4/nmt.model \
  --model-config ../part4/model_config.yaml \
  --vocab-file ../part2/vocab/vocab.json \
  --do-sample \
  --top-k 70 \
  --top-p 0.7 \
  --temperature 0.8
# Out:
# load vocab from ..\part2\vocab\vocab.json
# Load model from ..\part4\nmt.model
# Number of parameters: 8455296 (8.46M)
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\gulla\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Traceback (most recent call last):
#   File "c:\Users\gulla\OneDrive\Documents\uni\nlp\cw2\newcw2\nlp_cw2\part2\predict.py", line 193, in <module>
#     predict(args)
#   File "c:\Users\gulla\OneDrive\Documents\uni\nlp\cw2\newcw2\nlp_cw2\part2\predict.py", line 75, in predict
#     sp.load("vocab/spm.model")
#   File "c:\Users\gulla\OneDrive\Documents\uni\nlp\cw2\newcw2\nlp_cw2\.venv\Lib\site-packages\sentencepiece\__init__.py", line 961, in Load
#     return self.LoadFromFile(model_file)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\gulla\OneDrive\Documents\uni\nlp\cw2\newcw2\nlp_cw2\.venv\Lib\site-packages\sentencepiece\__init__.py", line 316, in LoadFromFile
#     return _sentencepiece.SentencePieceProcessor_LoadFromFile(self, arg)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# OSError: Not found: "vocab/spm.model": No such file or directory Error #2

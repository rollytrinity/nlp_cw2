# %%
import csv

with open('test_2016_flickr.fr') as file:
    gold = file.readlines()

# %%
noir = [i for i in gold if 'noir' in i]
en_noir = [i for i in noir if 'en noir' in i]

print('No of en_noirs: ' + str(len(en_noir)))
print('No of noirs: ' + str(len(noir)))
# Out:
# No of en_noirs: 19
# No of noirs: 83

# %%
est_en_noir = [i for i in 'noir' if 'est en noir' in i]
est_en_noir
# Out:
# []

# %%
rouge = [i for i in gold if 'rouge' in i]
en_rouge = [i for i in gold if 'en rouge' in i]

# %%
print(len(rouge))
print(len(en_rouge))
# Out:
# 55
# 2
